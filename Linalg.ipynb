# %%
from Vector import Vector

# %%
myVec1 = Vector([1,2,3])

# %%
myVec2 = Vector([-1,1,1])

# %%
print(myVec1 + myVec2)
# Out:
# (0, 3, 4)

# %%
print(myVec2.getDirection())
# Out:
# (-0.5773502691896258, 0.5773502691896258, 0.5773502691896258)

# %%
print(myVec1 * 2)
# Out:
# (2, 4, 6)

# %%
#this is broken right now
print(myVec1 * myVec2)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-12-54996732dca2> in <module>()
#       1 #this is broken right now
# ----> 2 print(myVec1 * myVec2)
#
# /home/cody/Code/linalg/Vector.py in __mul__(self, other)
#      32     def __mul__(self, other):
#      33         if type(other) is Vector:
# ---> 34             theta = math.acos(operator.mul(self.getDirection(), other.getDirection()))
#      35             return operator.mul(self.getMagnitude(), other.getMagnitude(), math.cos(theta))
#      36         else:
#
# /home/cody/Code/linalg/Vector.py in __mul__(self, other)
#      32     def __mul__(self, other):
#      33         if type(other) is Vector:
# ---> 34             theta = math.acos(operator.mul(self.getDirection(), other.getDirection()))
#      35             return operator.mul(self.getMagnitude(), other.getMagnitude(), math.cos(theta))
# ...
